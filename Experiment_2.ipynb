# %% [markdown]
# ## **Experiment-2 PART A**

# %%
# Roll No: 24BAD031

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)

sigmoid = 1 / (1 + np.exp(-x))
tanh = np.tanh(x)
relu = np.maximum(0, x)

plt.figure(figsize=(8,5))
plt.plot(x, sigmoid, label="Sigmoid")
plt.plot(x, tanh, label="Tanh")
plt.plot(x, relu, label="ReLU")
plt.title("Activation Functions")
plt.xlabel("x")
plt.ylabel("Output")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Experiment-2 PART B**

# %%
# Roll No: 24BAD031
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(-1,784)/255.0
X_test = X_test.reshape(-1,784)/255.0

# Function to create model
def create_model(act):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(128, activation=act, input_shape=(784,)),
        tf.keras.layers.Dense(64, activation=act),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

for act in ["sigmoid", "tanh", "relu"]:
    print("\nActivation:", act)

    model = create_model(act)

    model.fit(
        X_train,
        y_train,
        epochs=5,
        validation_split=0.2,
        verbose=1
    )

    loss, acc = model.evaluate(X_test, y_test)

    print("Test Accuracy:", acc)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Activation: sigmoid
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8734 - loss: 0.5209 - val_accuracy: 0.9350 - val_loss: 0.2302
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9413 - loss: 0.2015 - val_accuracy: 0.9506 - val_loss: 0.1665
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9578 - loss: 0.1408 - val_accuracy: 0.9595 - val_loss: 0.1368
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9685 - loss: 0.1053 - val_accuracy: 0.9679 - val_loss: 0.1090
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9760 - loss: 0.0816 - val_accuracy: 0.9711 - val_loss: 0.0987
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9687 - loss: 0.1014
# Test Accuracy: 0.9686999917030334
#
# Activation: tanh
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9161 - loss: 0.2878 - val_accuracy: 0.9486 - val_loss: 0.1747
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9598 - loss: 0.1337 - val_accuracy: 0.9643 - val_loss: 0.1209
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9722 - loss: 0.0905 - val_accuracy: 0.9695 - val_loss: 0.1025
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9809 - loss: 0.0633 - val_accuracy: 0.9712 - val_loss: 0.0932
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9847 - loss: 0.0494 - val_accuracy: 0.9718 - val_loss: 0.0933
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9747 - loss: 0.0841
# Test Accuracy: 0.9746999740600586
#
# Activation: relu
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9227 - loss: 0.2684 - val_accuracy: 0.9603 - val_loss: 0.1378
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9659 - loss: 0.1128 - val_accuracy: 0.9643 - val_loss: 0.1215
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9764 - loss: 0.0777 - val_accuracy: 0.9673 - val_loss: 0.1029
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9812 - loss: 0.0599 - val_accuracy: 0.9720 - val_loss: 0.0943
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9851 - loss: 0.0470 - val_accuracy: 0.9727 - val_loss: 0.1011
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9749 - loss: 0.0905
# Test Accuracy: 0.9749000072479248

# %% [markdown]
# ## **Experiment-2 PART C**

# %%
# Roll No:24BAD031

import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize data
X_train = X_train.reshape(-1, 784) / 255.0
X_test = X_test.reshape(-1, 784) / 255.0

# Optimizers
optimizers = {
    "SGD": tf.keras.optimizers.SGD(),
    "Momentum": tf.keras.optimizers.SGD(momentum=0.9),
    "RMSProp": tf.keras.optimizers.RMSprop(),
    "Adam": tf.keras.optimizers.Adam()
}

# Store histories
histories = {}

# Train models
for name, optimizer in optimizers.items():

    print("\nTraining with", name)

    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(784,)),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    history = model.fit(
        X_train,
        y_train,
        epochs=5,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )

    histories[name] = history

    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)

    print(f"{name}")
    print("Test Loss :", round(loss, 4))
    print("Test Accuracy :", round(accuracy, 4))

# ---------------- Loss Graph ----------------

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)

for name in histories:
    plt.plot(histories[name].history["loss"], label=name)

plt.title("Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# ---------------- Accuracy Graph ----------------

plt.subplot(1,2,2)

for name in histories:
    plt.plot(histories[name].history["accuracy"], label=name)

plt.title("Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Training with SGD
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8098 - loss: 0.7203 - val_accuracy: 0.9068 - val_loss: 0.3323
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9107 - loss: 0.3153 - val_accuracy: 0.9241 - val_loss: 0.2614
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9258 - loss: 0.2599 - val_accuracy: 0.9345 - val_loss: 0.2284
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9358 - loss: 0.2246 - val_accuracy: 0.9413 - val_loss: 0.2054
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9436 - loss: 0.1986 - val_accuracy: 0.9470 - val_loss: 0.1884
# SGD
# Test Loss : 0.1861
# Test Accuracy : 0.9465
#
# Training with Momentum
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9012 - loss: 0.3263 - val_accuracy: 0.9467 - val_loss: 0.1797
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9587 - loss: 0.1401 - val_accuracy: 0.9667 - val_loss: 0.1185
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9720 - loss: 0.0951 - val_accuracy: 0.9640 - val_loss: 0.1199
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9779 - loss: 0.0731 - val_accuracy: 0.9697 - val_loss: 0.1049
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9824 - loss: 0.0579 - val_accuracy: 0.9714 - val_loss: 0.0997
# Momentum
# Test Loss : 0.0909
# Test Accuracy : 0.9719
#
# Training with RMSProp
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9237 - loss: 0.2589 - val_accuracy: 0.9622 - val_loss: 0.1289
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9659 - loss: 0.1135 - val_accuracy: 0.9699 - val_loss: 0.1017
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9756 - loss: 0.0816 - val_accuracy: 0.9732 - val_loss: 0.0971
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9800 - loss: 0.0647 - val_accuracy: 0.9729 - val_loss: 0.0945
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9847 - loss: 0.0534 - val_accuracy: 0.9749 - val_loss: 0.0980
# RMSProp
# Test Loss : 0.0918
# Test Accuracy : 0.9766
#
# Training with Adam
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9229 - loss: 0.2650 - val_accuracy: 0.9596 - val_loss: 0.1327
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9660 - loss: 0.1140 - val_accuracy: 0.9651 - val_loss: 0.1125
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9756 - loss: 0.0802 - val_accuracy: 0.9677 - val_loss: 0.1036
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9814 - loss: 0.0590 - val_accuracy: 0.9734 - val_loss: 0.0943
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9854 - loss: 0.0455 - val_accuracy: 0.9701 - val_loss: 0.1128
# Adam
# Test Loss : 0.1049
# Test Accuracy : 0.97

# %% [markdown]
# ## **Experiment-2 PART D**

# %%
# Roll No:24BAD031

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Save model
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(10)
])

model.save("/content/drive/MyDrive/ann_model.h5")

print("Model Saved Successfully")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Mounted at /content/drive
# Model Saved Successfully
