# %% [markdown]
# ## **Experiment-2 PART A**

# %%
# Roll No: 24BAD052

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)

sigmoid = 1 / (1 + np.exp(-x))
tanh = np.tanh(x)
relu = np.maximum(0, x)

plt.figure(figsize=(8,5))
plt.plot(x, sigmoid, label="Sigmoid")
plt.plot(x, tanh, label="Tanh")
plt.plot(x, relu, label="ReLU")
plt.title("Activation Functions")
plt.xlabel("x")
plt.ylabel("Output")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Experiment-2 PART B**

# %%
# Roll No: 24BAD052
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(-1,784)/255.0
X_test = X_test.reshape(-1,784)/255.0

# Function to create model
def create_model(act):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(128, activation=act, input_shape=(784,)),
        tf.keras.layers.Dense(64, activation=act),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

for act in ["sigmoid", "tanh", "relu"]:
    print("\nActivation:", act)

    model = create_model(act)

    model.fit(
        X_train,
        y_train,
        epochs=5,
        validation_split=0.2,
        verbose=1
    )

    loss, acc = model.evaluate(X_test, y_test)

    print("Test Accuracy:", acc)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Activation: sigmoid
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8700 - loss: 0.5308 - val_accuracy: 0.9337 - val_loss: 0.2337
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9413 - loss: 0.2049 - val_accuracy: 0.9515 - val_loss: 0.1677
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9565 - loss: 0.1461 - val_accuracy: 0.9606 - val_loss: 0.1363
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9670 - loss: 0.1099 - val_accuracy: 0.9654 - val_loss: 0.1173
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9750 - loss: 0.0862 - val_accuracy: 0.9693 - val_loss: 0.1043
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9698 - loss: 0.0998
# Test Accuracy: 0.9697999954223633
#
# Activation: tanh
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9163 - loss: 0.2881 - val_accuracy: 0.9477 - val_loss: 0.1720
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9590 - loss: 0.1363 - val_accuracy: 0.9626 - val_loss: 0.1254
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9719 - loss: 0.0936 - val_accuracy: 0.9646 - val_loss: 0.1161
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9788 - loss: 0.0683 - val_accuracy: 0.9697 - val_loss: 0.0983
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9843 - loss: 0.0508 - val_accuracy: 0.9701 - val_loss: 0.0944
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9755 - loss: 0.0844
# Test Accuracy: 0.9754999876022339
#
# Activation: relu
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9207 - loss: 0.2704 - val_accuracy: 0.9583 - val_loss: 0.1388
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9657 - loss: 0.1119 - val_accuracy: 0.9658 - val_loss: 0.1119
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9759 - loss: 0.0765 - val_accuracy: 0.9707 - val_loss: 0.1022
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9822 - loss: 0.0567 - val_accuracy: 0.9707 - val_loss: 0.1046
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9859 - loss: 0.0449 - val_accuracy: 0.9738 - val_loss: 0.0953
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9744 - loss: 0.0891
# Test Accuracy: 0.974399983882904

# %% [markdown]
# ## **Experiment-2 PART C**

# %%
# Roll No:24BAD052

import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize data
X_train = X_train.reshape(-1, 784) / 255.0
X_test = X_test.reshape(-1, 784) / 255.0

# Optimizers
optimizers = {
    "SGD": tf.keras.optimizers.SGD(),
    "Momentum": tf.keras.optimizers.SGD(momentum=0.9),
    "RMSProp": tf.keras.optimizers.RMSprop(),
    "Adam": tf.keras.optimizers.Adam()
}

# Store histories
histories = {}

# Train models
for name, optimizer in optimizers.items():

    print("\nTraining with", name)

    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(784,)),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    history = model.fit(
        X_train,
        y_train,
        epochs=5,
        batch_size=32,
        validation_split=0.2,
        verbose=1
    )

    histories[name] = history

    loss, accuracy = model.evaluate(X_test, y_test, verbose=0)

    print(f"{name}")
    print("Test Loss :", round(loss, 4))
    print("Test Accuracy :", round(accuracy, 4))

# ---------------- Loss Graph ----------------

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)

for name in histories:
    plt.plot(histories[name].history["loss"], label=name)

plt.title("Loss vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# ---------------- Accuracy Graph ----------------

plt.subplot(1,2,2)

for name in histories:
    plt.plot(histories[name].history["accuracy"], label=name)

plt.title("Accuracy vs Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Training with SGD
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8216 - loss: 0.6877 - val_accuracy: 0.9084 - val_loss: 0.3281
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9133 - loss: 0.3098 - val_accuracy: 0.9260 - val_loss: 0.2596
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9273 - loss: 0.2544 - val_accuracy: 0.9350 - val_loss: 0.2288
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9368 - loss: 0.2208 - val_accuracy: 0.9442 - val_loss: 0.2003
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9435 - loss: 0.1954 - val_accuracy: 0.9488 - val_loss: 0.1838
# SGD
# Test Loss : 0.1827
# Test Accuracy : 0.9451
#
# Training with Momentum
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9042 - loss: 0.3175 - val_accuracy: 0.9572 - val_loss: 0.1501
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9598 - loss: 0.1342 - val_accuracy: 0.9641 - val_loss: 0.1163
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9721 - loss: 0.0922 - val_accuracy: 0.9676 - val_loss: 0.1057
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9776 - loss: 0.0708 - val_accuracy: 0.9721 - val_loss: 0.0943
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9824 - loss: 0.0560 - val_accuracy: 0.9706 - val_loss: 0.0997
# Momentum
# Test Loss : 0.0871
# Test Accuracy : 0.9717
#
# Training with RMSProp
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9235 - loss: 0.2629 - val_accuracy: 0.9508 - val_loss: 0.1660
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9663 - loss: 0.1136 - val_accuracy: 0.9671 - val_loss: 0.1133
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9762 - loss: 0.0810 - val_accuracy: 0.9693 - val_loss: 0.1104
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9806 - loss: 0.0647 - val_accuracy: 0.9696 - val_loss: 0.1119
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9847 - loss: 0.0513 - val_accuracy: 0.9723 - val_loss: 0.1119
# RMSProp
# Test Loss : 0.0948
# Test Accuracy : 0.9758
#
# Training with Adam
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9208 - loss: 0.2679 - val_accuracy: 0.9592 - val_loss: 0.1419
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9669 - loss: 0.1103 - val_accuracy: 0.9645 - val_loss: 0.1191
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9778 - loss: 0.0746 - val_accuracy: 0.9724 - val_loss: 0.0983
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9823 - loss: 0.0556 - val_accuracy: 0.9732 - val_loss: 0.0958
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9859 - loss: 0.0447 - val_accuracy: 0.9722 - val_loss: 0.0988
# Adam
# Test Loss : 0.0917
# Test Accuracy : 0.9733

# %% [markdown]
# ## **Experiment-2 PART D**

# %%
# Roll No: 24BAD052

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Import TensorFlow
import tensorflow as tf

# Create a simple model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
])

# Save the model
model.save('/content/drive/MyDrive/ann_model.keras')

print("Model Saved Successfully!")
# Out:
# Mounted at /content/drive
# Model Saved Successfully!
